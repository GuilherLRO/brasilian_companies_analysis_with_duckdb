# %%
import duckdb
import os

# %%
conn = duckdb.connect('cnpj.db')

# %%
tables = conn.execute("SHOW TABLES").fetchall()
tables = [t[0] for t in tables]
print(tables)
# Out:
# ['cnae', 'cnae_raw', 'empresas', 'empresas_raw', 'estabelecimentos', 'estabelecimentos_raw', 'natureza', 'natureza_raw', 'simple', 'simple_raw', 'simples_raw', 'socios', 'socios_raw']

# %%
for table in tables:
    count = conn.execute(f"SELECT COUNT(*) FROM {table}").df().iloc[0,0]
    print(f"{table}: {count}")
# Out:
# cnae: 1358
# cnae_raw: 1358
# empresas: 56554309
# empresas_raw: 56554309
# estabelecimentos: 59495409
# estabelecimentos_raw: 59495409
# natureza: 89
# natureza_raw: 89
# simple: 38371644
# simple_raw: 38371644
# simples_raw: 0
# socios: 23765603
# socios_raw: 23765603

# %%
display(conn.execute(""" SELECT * FROM EMPRESAS WHERE legal_nature = '0000' AND responsible_qualification = '00' AND company_size = ''""").df())
# Out:
#   cnpj_base social_name legal_nature responsible_qualification capital  \
# 0  08504420                     0000                        00    0,00
# 1  08725575                     0000                        00    0,00
#
#   company_size federal_entity_responsible
# 0
# 1

# %%
conn.execute("""SELECT * FROM EMPRESAS WHERE CNPJ_BASE = '08725575'""").df()
# Out:
#   cnpj_base                     social_name legal_nature  \
# 0  08725575  ALVARO JOSE LOURENZATO E OUTRA         4120
# 1  08725575                                         0000
#
#   responsible_qualification capital company_size federal_entity_responsible
# 0                        59    0,00           05
# 1                        00    0,00

# %%
display(conn.execute("""SELECT CNPJ_BASE, SUM(CAST(CNPJ_BASE AS INT)) / AVG(CAST(CNPJ_BASE AS INT)), 
                      FROM EMPRESAS
                     GROUP BY 1
                     ORDER BY 2 DESC""").df())
# Out:
#          cnpj_base  \
# 0         08725575
# 1         27622681
# 2         27622688
# 3         27622704
# 4         27622743
# ...            ...
# 56554303  08945877
# 56554304  08945901
# 56554305  08945915
# 56554306  08945939
# 56554307  08945957
#
#           (sum(CAST(CNPJ_BASE AS INTEGER)) / avg(CAST(CNPJ_BASE AS INTEGER)))
# 0                                                       2.0
# 1                                                       1.0
# 2                                                       1.0
# 3                                                       1.0
# 4                                                       1.0
# ...                                                     ...
# 56554303                                                1.0
# 56554304                                                1.0
# 56554305                                                1.0
# 56554306                                                1.0
# ...

# %%
conn.execute("""DESCRIBE estabelecimentos""").df()
# Out:
#             column_name column_type null   key default extra
# 0             cnpj_base     VARCHAR  YES  None    None  None
# 1            cnpj_order     VARCHAR  YES  None    None  None
# 2               cnpj_dv     VARCHAR  YES  None    None  None
# 3            identifier     VARCHAR  YES  None    None  None
# 4          fantasy_name     VARCHAR  YES  None    None  None
# 5   registration_status     VARCHAR  YES  None    None  None
# 6     registration_date     VARCHAR  YES  None    None  None
# 7   registration_reason     VARCHAR  YES  None    None  None
# 8             city_name     VARCHAR  YES  None    None  None
# 9          country_code     VARCHAR  YES  None    None  None
# 10  activity_start_date     VARCHAR  YES  None    None  None
# 11        main_activity     VARCHAR  YES  None    None  None
# 12   secondary_activity     VARCHAR  YES  None    None  None
# 13          street_type     VARCHAR  YES  None    None  None
# ...

# %%
conn.close()
